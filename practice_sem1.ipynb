# %% [markdown]
# # Практическое задание 1. Работа с библиотекой Pandas (Spotify Edition)
#
# В этом задании мы будем работать с реальными данными о треках из Spotify. Задание поможет вам закрепить навыки работы с библиотекой Pandas в контексте анализа музыкальных предпочтений и аудио-характеристик.
# Пожалуйста, не используйте циклы (for, while) для обработки данных в pandas — это считается плохой практикой и снижает оценку. Используйте векторизованные операции.
#
# ## Часть 1. Знакомство с данными (Spotify Songs)
#
# Для начала скачаем датасет о 32 000+ треках Spotify из открытого источника TidyTuesday.

# %%
import pandas as pd
import numpy as np

# Загружаем датасет по прямой ссылке
url = "https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-01-21/spotify_songs.csv"
data = pd.read_csv(url)

# Посмотрим на первые 5 строк
data.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# ...

# %% [markdown]
# ### Задание 1
# Выведите размерность данных (количество строк и столбцов).

# %%
# ВАШ КОД ЗДЕСЬ
data.shape
# Out:
# (32833, 23)

# %% [markdown]
# ### Задание 2
# Посмотрите на общую информацию о данных (`info`). Выведите количество уникальных музыкальных жанров (`playlist_genre`) в датасете.

# %%
# ВАШ КОД ЗДЕСЬ
data.info()
data["playlist_genre"].value_counts()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  str
#  1   track_name                32828 non-null  str
#  2   track_artist              32828 non-null  str
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  str
#  5   track_album_name          32828 non-null  str
#  6   track_album_release_date  32833 non-null  str
#  7   playlist_name             32833 non-null  str
#  8   playlist_id               32833 non-null  str
#  9   playlist_genre            32833 non-null  str
#  10  playlist_subgenre         32833 non-null  str
#  11  danceability              32833 non-null  float64
#  12  energy                    32833 non-null  float64
#  13  key                       32833 non-null  int64
# ...

# %% [markdown]
# ### Задание 3
# Найдите пропущенные значения в колонках `track_name` и `track_artist`. Заполните их строкой 'Unknown' и убедитесь, что пропусков больше не осталось.

# %%
# ВАШ КОД ЗДЕСЬ
data[["track_name", "track_artist"]].fillna("Unknown")
data[["track_name", "track_artist"]].isna()
# Out:
#        track_name  track_artist
# 0           False         False
# 1           False         False
# 2           False         False
# 3           False         False
# 4           False         False
# ...           ...           ...
# 32828       False         False
# 32829       False         False
# 32830       False         False
# 32831       False         False
# 32832       False         False
#
# [32833 rows x 2 columns]

# %% [markdown]
# ### Задание 4
# В датасете есть колонка `mode`, которая указывает лад трека (1 - мажор, 0 - минор). Сравните среднюю танцевальность (`danceability`) мажорных и минорных треков. Какой лад в среднем более танцевальный?

# %%
# ВАШ КОД ЗДЕСЬ

# %% [markdown]
# ## Задание 1
#
# В этой части мы напишем алгоритм отбора лучших треков для тематических плейлистов, заменяющий оригинальную задачу распределения студентов.
#
# Представим, что мы создаем 3 эксклюзивных плейлиста для музыкального фестиваля:
# 1. **EDM Main Stage** (включает жанры: `edm`)
# 2. **Indie Lounge** (включает жанры: `pop`, `r&b`)
# 3. **Rock Arena** (включает жанры: `rock`)
#
# У каждого плейлиста есть лимит — ровно 100 треков.
#
# **Условия распределения:**
# * Треки подают "заявку" в плейлист в зависимости от своего жанра (`playlist_genre`). Один трек может претендовать только на одну сцену. Если жанр трека не подходит ни для одной из сцен, мы его игнорируем.
# * Треки соревнуются за места на основе своей популярности (`track_popularity`). Чем выше популярность, тем раньше трек занимает место.
# * Если популярность совпадает, в первую очередь берется трек с бóльшим значением `danceability`. Если и они равны — порядок не важен.
# * Один и тот же трек (один и тот же `track_name` + `track_artist`) может попасть в датасет несколько раз (если он в разных альбомах). Перед распределением обязательно **удалите полные дубликаты** по связке (track_name, track_artist).
#
# ### Ваша задача:
# Написать алгоритм распределения, который сформирует три `DataFrame` (по одному на каждый плейлист), содержащих **до 100 лучших треков**, удовлетворяющих условиям. Отсортируйте итоговые плейлисты по убыванию популярности.

# %%
# Подсказка: начните с очистки дубликатов
data_unique = data.drop_duplicates(subset=['track_name', 'track_artist']).copy()

# Инициализируем пустые DataFrame для плейлистов
edm_main_stage = pd.DataFrame()
indie_lounge = pd.DataFrame()
rock_arena = pd.DataFrame()

# ВАШ КОД ЗДЕСЬ

# %% [markdown]
# ### Проверка распределения
# Напишите код, который проверяет:
# 1. Что в каждом плейлисте не больше 100 треков.
# 2. Что жанры треков соответствуют заявленным сценам.

# %%
# ВАШ КОД ЗДЕСЬ

# %% [markdown]
# ---
# ### Задание 1. Разминка (Matplotlib)
# Постройте диаграмму рассеяния (`plt.scatter`), показывающую зависимость популярности трека (`track_popularity`) от его энергичности (`energy`).
#
# **Требования:**
# - Используйте данные из датасета `data`.
# - Обязательно подпишите оси (xlabel, ylabel).
# - Добавьте заголовок графику (title).
# - (Опционально) Задайте размер графика через `plt.figure(figsize=(...))` и сделайте точки полупрозрачными (`alpha=0.5`).

# %%
# ВАШ КОД ЗДЕСЬ

# %% [markdown]
# ---
# ### Задание 2. Сводные таблицы и Heatmap (Seaborn)
# Музыка бывает в мажорном (`mode=1`) и минорном (`mode=0`) ладу. Интересно узнать, в каких жанрах мажор более танцевальный, чем минор?
#
# **Требования:**
# 1. Используя метод `.pivot_table()`, создайте сводную таблицу `pivot_dance`.
#    - Индексы (`index`) — жанры (`playlist_genre`).
#    - Колонки (`columns`) — лад (`mode`).
#    - Значения (`values`) — средняя танцевальность (`danceability`).
# 2. Визуализируйте полученную таблицу с помощью `sns.heatmap`. Обязательно добавьте параметр `annot=True`, чтобы видеть числа в ячейках.

# %%
# ВАШ КОД ЗДЕСЬ

# %% [markdown]
# ---
# ### Задание 3. Суперпуперкреатив
# Постройте любой график на датасете вашего выбора
#
# **Требования:**
# 1. Читабельный график
# 2. Нормальная тема (умоляю 🙏)

# %%
# ВАШ КОД ЗДЕСЬ
